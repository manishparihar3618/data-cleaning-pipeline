# %%
import pandas as pd
df = pd.read_csv('raw_data.csv')
def clean_data(df):
    df = df.dropna()
    df = df.drop_duplicates()

# now print the first 5 rows of the cleaned dataframe
    print(df.head())
    return df
cleaned_df = clean_data(df)

cleaned_df.to_csv('cleaned_data.csv', index=False)
print("Data cleaning complete. Cleaned data saved to 'cleaned_data.csv'.")
# Out:
#     Name  Math  Science  English  Attendance
# 0  Aarav  78.0     85.0     88.0        92.0
# 2  Rahul  45.0     52.0     48.0        70.0
# 3  Sneha  90.0     91.0     89.0        95.0
# 5   Neha  76.0     80.0     78.0        88.0
# 9  Rohit  55.0     58.0     54.0        68.0
# Data cleaning complete. Cleaned data saved to 'cleaned_data.csv'.
